# %%
# Required imports
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from pathlib import Path
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Define the path to the CSV file
path_to_csv = Path(r"C:\Users\trans\Documents\School\Berekeley Data\Project4-Team7\Resources\stats.csv")

# Read the CSV file into a DataFrame
df = pd.read_csv(path_to_csv)

# Display the first few rows of the DataFrame
df.head()
# Out:
#   last_name, first_name  player_id  year   pa  hit  single  double  triple  \
# 0         Hunter, Torii     116338  2015  567  125      81      22       0
# 1          Ortiz, David     120074  2015  614  144      70      37       0
# 2       Rodriguez, Alex     121347  2015  620  131      75      22       1
# 3       Ramirez, Aramis     133380  2015  516  117      68      31       1
# 4        Beltré, Adrián     134181  2015  619  163     109      32       4
#
#    home_run  strikeout  ...  slg_percent   woba  xwoba  sweet_spot_percent  \
# 0        22        105  ...        0.409  0.304  0.290                28.5
# 1        37         95  ...        0.553  0.379  0.420                34.8
# 2        33        145  ...        0.486  0.361  0.368                31.4
# 3        17         68  ...        0.423  0.309  0.304                33.5
# 4        18         65  ...        0.453  0.337  0.360                35.7
#
# ...

# %%
# Select the columns "sweet_spot_percent" and "home_run"
selected_columns = df[["sweet_spot_percent", "home_run"]]

# Drop rows with NaN values if needed
selected_columns = selected_columns.dropna()

# Perform KMeans clustering
kmeans = KMeans(n_clusters=3)
kmeans.fit(selected_columns)

# Add a new column to the DataFrame with the cluster labels
selected_columns['cluster'] = kmeans.labels_

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(selected_columns['sweet_spot_percent'], selected_columns['home_run'], c=selected_columns['cluster'], cmap='viridis')
plt.xlabel('Sweet Spot Percent')
plt.ylabel('Home Run')
plt.title('Cluster Graph of Sweet Spot Percent vs Home Run')
plt.show()
# Out:
# c:\Users\trans\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
